# %%
cd vit-research
# Out:
# [Errno 2] No such file or directory: 'vit-research'
# /sdb-disk/notebooks/team1/team01-res/vit-research

# %%
# !ls -l scripts/run_databudget_sweep.sh scripts/plot_databudget_comparison.py
# Out:
# ls: cannot access 'scripts/run_databudget_sweep.sh': No such file or directory
# ls: cannot access 'scripts/plot_databudget_comparison.py': No such file or directory

# %%
# !git checkout main
# !git pull origin main
# Out:
# Switched to branch 'main'
# Your branch is behind 'origin/main' by 17 commits, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# From https://github.com/shahin1717/vit-research
#  * branch            main       -> FETCH_HEAD
# Updating abdb939..970965b
# Fast-forward
#  .gitattributes                          |   4 +
#  .gitignore                              |  15 ++
#  configs/baseline_k0_300pc.yaml          |  40 ++++
#  configs/vit_tiny_k1_300pc.yaml          |  40 ++++
#  configs/vit_tiny_k4_300pc.yaml          |  40 ++++
#  configs/vit_tiny_k8_300pc.yaml          |  40 ++++
#  contribution_report.pdf                 | Bin 0 -> 6254 bytes
#  paper/figures/accuracy_100_vs_300.pdf   | Bin 0 -> 21432 bytes
#  paper/figures/accuracy_100_vs_300.png   | Bin 0 -> 114841 bytes
#  paper/figures/accuracy_vs_registers.pdf | Bin 0 -> 17417 bytes
#  paper/figures/entropy_vs_layer.pdf      | Bin 0 -> 23753 bytes
# ...

# %%
ls
# Out:
# checkpoints/                        pytest.ini
# compute_request_and_budget.md       README.md
# configs/                            requirements.txt
# data/                               research_and_grill_analysis.md
# dl_final_project_task_breakdown.md  roadmap.md
# docs/                               scripts/
# fields.yaml                         src/
# notebooks/                          tasks/
# outline.yaml                        team_task_division.md
# outputs/                            tests/
# paper/                              vit_registers_proposal.md
# presentation/

# %%
# !git log -n 3
# Out:
# commit 6e7899dad192291bfc9bc4391af54e9cc5ac2170 (HEAD -> feat/paper-and-analysis, origin/feat/paper-and-analysis)
# Author: Rufet Dosteliyev <rufetdosteliyev@gmail.com>
# Date:   Tue Sep 8 22:47:33 2026 +0400
#
#     test(metrics): compare the register-offset rate against its own baseline
#
# commit d405cd0a36ae19c42db409853419d0500ec930a7
# Author: Rufet Dosteliyev <rufetdosteliyev@gmail.com>
# Date:   Tue Sep 8 22:47:33 2026 +0400
#
#     fix(utils): write the LaTeX tables with LF endings on every platform
#
# commit c9ed7e07a7894a6b53b8548dd415ca5483f0e681
# Author: Rufet Dosteliyev <rufetdosteliyev@gmail.com>
# Date:   Tue Sep 8 20:30:21 2026 +0400
#
#     docs: add the compiled manuscript PDF
