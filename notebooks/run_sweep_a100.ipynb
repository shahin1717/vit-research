# %%
# !bash scripts/run_sweep.sh
# Out:
# ...
# Starting 12-Run ViT Register Ablation Sweep Matrix
# ...
# Repository      : /sdb-disk/notebooks/team1/team01-res/vit-research
# Interpreter     : python
# Register arms   : 0 1 4 8
# Seeds           : 42 1337 3407
# Output root     : outputs
# Checkpoint root : checkpoints
# Started         : 2026-09-07 07:57:03
#
# ----------------------------------------------------------
# >> [1/12] Executing exp01_k0_s42 (K=0, Seed=42)
#    config=configs/baseline_k0.yaml  outputs=outputs/exp01_k0_s42  checkpoints=checkpoints/exp01_k0_s42
# ----------------------------------------------------------
# 2026-09-07 07:57:07 [INFO] train - Loading config file: configs/baseline_k0.yaml
# 2026-09-07 07:57:07 [INFO] train - Deterministic seed set to 42.
# 2026-09-07 07:57:07 [INFO] train - === Starting Experiment: rViT_K0_seed42 ===
# 2026-09-07 07:57:07 [INFO] train - Device: cuda | AMP: True | Registers K=0 | Seed: 42
# ...

# %%
cd vit-research
# Out:
# [Errno 2] No such file or directory: 'vit-research'
# /sdb-disk/notebooks/team1/team01-res/vit-research

# %%
# !bash scripts/run_databudget_sweep.sh
# Out:
# ...
# 🚀 Starting 300 Images/Class Data Budget Extension Sweep
# Interpreter: /nvme0n1-disk/venvs/jupyter_team1/bin/python3
# Arms: K in [0 1 4 8] | Seeds: [42 1337 3407]
# ...
#
# >> exp13_k0_pc300_s42  (K=0, budget=300/class, seed=42)
# 2026-09-10 10:51:26 [INFO] train - Loading config file: configs/baseline_k0_300pc.yaml
# 2026-09-10 10:51:26 [INFO] train - Deterministic seed set to 42.
# 2026-09-10 10:51:26 [INFO] train - === Starting Experiment: vit_tiny_baseline_k0_300pc ===
# 2026-09-10 10:51:26 [INFO] train - Device: cuda | AMP: True | Registers K=0 | Seed: 42
# 2026-09-10 10:51:28 [INFO] train - Dataloaders ready. Train batches: 422, Val batches: 47
# 2026-09-10 10:51:29 [INFO] timm.models._builder - Loading pretrained weights from Hugging Face hub (timm/vit_tiny_patch16_224.augreg_in21k_ft_in1k)
# 2026-09-10 10:51:29 [INFO] httpx - HTTP Request: HEAD https://huggingface.co/timm/vit_tiny_patch16_224.augreg_in21k_ft_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# ...

# %%
# !python src/utils/aggregate_databudget.py --output_dir outputs_databudget
# Out:
# ✅ Successfully generated aggregated summary at: outputs_databudget/summary.json
# ...
# Arm       Seeds  Test Top-1 (%)      Gen Gap     Val Loss
# ------------------------------------------------------------
# K=0       1      22.94 ± 0.00        -0.8032     3.3799
# ...

# %%
# !python scripts/plot_databudget_comparison.py
