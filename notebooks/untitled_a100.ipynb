# %%
cd vit-research
# Out:
# /sdb-disk/notebooks/team1/team01-res/vit-research

# %%
# !git add .

# %%
# !git commit -m "runned experiments"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git config --global user.email "sahinalekperov5@gmail.com"

# %%
# !git config --global user.name "Shahin1717"

# %%
# !git fetch origin && git checkout feat/paper-and-analysis && pip install -q matplotlib && python scripts/visualize_attention.py --baseline outputs/exp01_k0_s42/best_model.pth --registers outputs/exp07_k4_s42/best_model.pth
# Out:
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 57 (delta 20), reused 57 (delta 20), pack-reused 0 (from 0)
# Unpacking objects: 100% (57/57), 290.54 KiB | 2.25 MiB/s, done.
# From https://github.com/shahin1717/vit-research
#  * [new branch]      feat/paper-and-analysis -> origin/feat/paper-and-analysis
# branch 'feat/paper-and-analysis' set up to track 'origin/feat/paper-and-analysis'.
# Switched to a new branch 'feat/paper-and-analysis'
# wrote paper/figures/attention_maps_comparison.pdf (test image 0, class 49)

# %%
# !nvidia-smi
# Out:
# Thu Sep 10 11:04:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.127.08             Driver Version: 550.127.08     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:81:00.0 Off |                   On |
# | N/A   75C    P0            124W /  400W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# ...
